# %%
from sqlalchemy import create_engine
from sqlalchemy import Column, Integer, String, Float
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
file_name_1 = os.path.join("../Resources", "cleaned_hawaii_measurements.csv")
file_name_2 = os.path.join("../Resources", "cleaned_hawaii_stations.csv")
data_1 = pd.read_csv(file_name_1)
data_2 = pd.read_csv(file_name_2)

# %%
engine = create_engine("sqlite:///databases/hawaii.sqlite")

# %%
class Measurement(Base):
    __tablename__ = 'measurement'
    id = Column(Integer, primary_key=True)
    station = Column(String(255))
    date = Column(String(255))

class Station(Base):
    __tablename__ = 'station'
    id = Column(Integer, primary_key=True)
    station = Column(String(255))
    elevation = Column(Integer)

# %%
engine = create_engine('mysql+pymysql://root:Wassup09!@localhost')  # connect to server
engine.execute("create database if not exists pets") #create db
engine.execute("hawaii_sqlite")
# Out:
# C:\Users\Patsy\Anaconda3\lib\site-packages\pymysql\cursors.py:165: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     469     def do_execute(self, cursor, statement, parameters, context=None):
# --> 470         cursor.execute(statement, parameters)
#     471
#
# ...
